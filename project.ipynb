# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("tn.csv")
df
# Out:
#     Table Code State Code District Code            Area Name  \
# 0      B0806SC        `33          `000   State - TAMIL NADU
# 1      B0806SC        `33          `000   State - TAMIL NADU
# 2      B0806SC        `33          `000   State - TAMIL NADU
# 3      B0806SC        `33          `000   State - TAMIL NADU
# 4      B0806SC        `33          `000   State - TAMIL NADU
# ..         ...        ...           ...                  ...
# 589    B0806SC        `33          `633  District - Tiruppur
# 590    B0806SC        `33          `633  District - Tiruppur
# 591    B0806SC        `33          `633  District - Tiruppur
# 592    B0806SC        `33          `633  District - Tiruppur
# 593    B0806SC        `33          `633  District - Tiruppur
#
#     Total/ Rural/ Urban       Age group  \
# 0                 Total           Total
# 1                 Total           `5-14
# 2                 Total           15-34
# 3                 Total           35-59
# ...

# %%
df.columns
# Out:
# Index(['Table Code', 'State Code', 'District Code', 'Area Name',
#        'Total/ Rural/ Urban', 'Age group',
#        'Worked for 3 months or more but less than 6 months -  Persons',
#        'Worked for 3 months or more but less than 6 months - Males',
#        'Worked for 3 months or more but less than 6 months - Females',
#        'Worked for less than 3 months - Persons',
#        'Worked for less than 3 months - Males',
#        'Worked for less than 3 months - Females',
#        'Industrial Category - A - Cultivators - Persons',
#        'Industrial Category - A - Cultivators - Males',
#        'Industrial Category - A - Cultivators - Females',
#        'Industrial Category - A - Agricultural labourers - Persons',
#        'Industrial Category - A - Agricultural labourers - Males',
#        'Industrial Category - A - Agricultural labourers - Females',
#        'Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 69 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Table Code                                                                                                   594 non-null    object
#  1   State Code                                                                                                   594 non-null    object
#  2   District Code                                                                                                594 non-null    object
#  3   Area Name                                                                                                    594 non-null    object
# ...

# %%
df.describe()
# Out:
#        Worked for 3 months or more but less than 6 months -  Persons  \
# count                                       5.940000e+02
# mean                                        1.617277e+04
# std                                         7.607172e+04
# min                                         0.000000e+00
# 25%                                         2.872500e+02
# 50%                                         2.225500e+03
# 75%                                         9.628500e+03
# max                                         1.200828e+06
#
#        Worked for 3 months or more but less than 6 months - Males  \
# count                                         594.000000
# mean                                         7932.700337
# std                                         36864.822704
# min                                             0.000000
# 25%                                           147.250000
# 50%                                          1147.000000
# ...

# %%
def personsUrbanOrRural(df):
    cols = df.columns

    base = ["Area Name","Total/ Rural/ Urban","Age group"]

    persons = [item for item in cols if item.endswith("Persons")]

    persons = base + persons

    persons = df[persons]

    persons = persons[persons["Age group"] == "Total" ]
    persons = persons[persons["Area Name"] != "State - TAMIL NADU"]

    persons = persons[persons["Total/ Rural/ Urban"] != "Total"]
    persons= persons.drop("Age group",axis=1)

    persons = persons.reset_index()

    persons = persons.drop("index",axis=1)
    persons
    industry = persons.columns
    print(industry)
    for i in range(2,len(industry)):
        pivot_data = persons.pivot(index='Area Name', columns='Total/ Rural/ Urban', values=[industry[i]])
        ax = pivot_data.plot(kind="bar",stacked=True,title=industry[i])
        legand_label = ["Rural","Urban"]
        ax.legend(labels=legand_label,loc='lower center', bbox_to_anchor=(0.5, 1.15))
        plt.show()

personsUrbanOrRural(df)
# Out:
# Index(['Area Name', 'Total/ Rural/ Urban',
#        'Worked for 3 months or more but less than 6 months -  Persons',
#        'Worked for less than 3 months - Persons',
#        'Industrial Category - A - Cultivators - Persons',
#        'Industrial Category - A - Agricultural labourers - Persons',
#        'Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons',
#        'Industrial Category - B - Persons',
#        'Industrial Category - C - HHI - Persons',
#        'Industrial Category - C - Non HHI - Persons',
#        'Industrial Category - D & E - Persons',
#        'Industrial Category - F - Persons',
#        'Industrial Category - G - HHI - Persons',
#        'Industrial Category - G - Non HHI - Persons',
#        'Industrial Category - H - Persons',
#        'Industrial Category - I - Persons',
#        'Industrial Category - J - HHI - Persons',
#        'Industrial Category - J - Non HHI - Persons',
# ...

# %%
def personsTotal(df):
    cols = df.columns

    base = ["Area Name","Total/ Rural/ Urban","Age group"]

    persons = [item for item in cols if item.endswith("Persons")]

    persons = base + persons

    persons = df[persons]

    persons = persons[persons["Age group"] == "Total" ]

    persons = persons[persons["Total/ Rural/ Urban"] == "Total"]

    persons= persons.drop("Age group",axis=1)
    persons = persons.drop("Total/ Rural/ Urban",axis=1)

    persons = persons.drop(0)

    persons = persons.reset_index()

    persons = persons.drop("index",axis=1)

    title=persons.columns


    for i in  range(1,len(title)):
        persons.plot(x="Area Name", y=title[i], kind='bar',legend=False)
        plt.ylabel(title[i])
        plt.show()
    
personsTotal(df)

# %%
df = df.drop(["Table Code","State Code","District Code"],axis=1)
col = df.columns

base = ['Area Name',
 'Total/ Rural/ Urban',
 'Age group']


withPersons = [item for item in col if item.endswith("Persons")]
withPersons = base + withPersons

withoutPersons = [item for item in col if not item.endswith("Persons")]
withoutPersons


withPersons = df[withPersons]
withoutPersons = df[withoutPersons]

withoutPersons
# Out:
#                Area Name Total/ Rural/ Urban       Age group  \
# 0     State - TAMIL NADU               Total           Total
# 1     State - TAMIL NADU               Total           `5-14
# 2     State - TAMIL NADU               Total           15-34
# 3     State - TAMIL NADU               Total           35-59
# 4     State - TAMIL NADU               Total             60+
# ..                   ...                 ...             ...
# 589  District - Tiruppur               Urban           `5-14
# 590  District - Tiruppur               Urban           15-34
# 591  District - Tiruppur               Urban           35-59
# 592  District - Tiruppur               Urban             60+
# 593  District - Tiruppur               Urban  Age not stated
#
#      Worked for 3 months or more but less than 6 months - Males  \
# 0                                               589003
# 1                                                14125
# ...

# %%
worked = withoutPersons.loc[:,"Area Name":"Worked for less than 3 months - Females"]
worked
# Out:
#                Area Name Total/ Rural/ Urban       Age group  \
# 0     State - TAMIL NADU               Total           Total
# 1     State - TAMIL NADU               Total           `5-14
# 2     State - TAMIL NADU               Total           15-34
# 3     State - TAMIL NADU               Total           35-59
# 4     State - TAMIL NADU               Total             60+
# ..                   ...                 ...             ...
# 589  District - Tiruppur               Urban           `5-14
# 590  District - Tiruppur               Urban           15-34
# 591  District - Tiruppur               Urban           35-59
# 592  District - Tiruppur               Urban             60+
# 593  District - Tiruppur               Urban  Age not stated
#
#      Worked for 3 months or more but less than 6 months - Males  \
# 0                                               589003
# 1                                                14125
# ...

# %%
common = withoutPersons.loc[:,"Area Name":"Age group"]
industryAData = withoutPersons.loc[:,"Industrial Category - A - Cultivators - Males":"Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Females"]
industryBData = withoutPersons.loc[:,"Industrial Category - B - Males":"Industrial Category - B - Females"]
industryCData = withoutPersons.loc[:,"Industrial Category - C - HHI - Males":"Industrial Category - C - Non HHI - Females"]
industryDEData = withoutPersons.loc[:,"Industrial Category - D & E - Males":"Industrial Category - D & E - Females"]
industryFData = withoutPersons.loc[:,"Industrial Category - F - Males":"Industrial Category - F - Females"]
industryGData = withoutPersons.loc[:,"Industrial Category - G - HHI - Males":"Industrial Category - G - Non HHI - Females"]
industryHData = withoutPersons.loc[:,"Industrial Category - H - Males":"Industrial Category - H - Females"]
industryIData = withoutPersons.loc[:,"Industrial Category - I - Males":"Industrial Category - I - Females"]
industryJData = withoutPersons.loc[:,"Industrial Category - J - HHI - Males":"Industrial Category - J - Non HHI - Females"]
industryKMData = withoutPersons.loc[:,"Industrial Category - K to M - Males":"Industrial Category - K to M - Females"]
industryNOData = withoutPersons.loc[:,"Industrial Category - N to O - Males":"Industrial Category - N to O - Females"]
industryRUData = withoutPersons.loc[:,"Industrial Category - R to U - HHI - Males":"Industrial Category - R to U - Non HHI - Females"]
industryPQData = withoutPersons.loc[:,"Industrial Category - P to Q - Males":"Industrial Category - P to Q - Females"]

# %%
industries = [industryAData,industryBData,industryCData,industryDEData,industryFData,industryGData,industryHData,industryIData,industryJData,industryKMData,industryPQData,industryRUData]

industriesName = ["industryA",'industryB','industryC','industryDE','industryF','industryG','industryH','industryI','industryJ','industryKM','industryPQ','industryRU']

for i in range(len(industriesName)):
    merged = [common,industries[i]]
    industriesName[i] = pd.concat(merged,axis=1)

# %%
districtName = withoutPersons["Area Name"].unique()

districtName

categories = withoutPersons["Total/ Rural/ Urban"].unique()
categories
# Out:
# array(['Total', 'Rural', 'Urban'], dtype=object)

# %%
def AnalysisByIndustry(industryData,district,category):
    district = industryData[industryData["Area Name"]==district]

    district = district.drop("Area Name", axis=1)

    district = district[district["Total/ Rural/ Urban"]==category]

    district = district.drop("Total/ Rural/ Urban",axis=1)

    district = district.drop(district.index[0])

    district.plot(x="Age group",kind="bar",stacked=True)

    plt.show()

AnalysisByIndustry(industriesName[1],"District - Tiruppur","Total")
